# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_colwidth',None)

# %%
df = pd.read_csv("potential.csv")

# %%
df.shape
# Out:
# (104, 5)

# %%
df = df.drop(columns='fit')

# %%
df.duplicated(keep=False).sum()
# Out:
# 0

# %%
# decription of the dataset
df.describe(include='all')
# Out:
#                 id  \
# count   104.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean     52.500000
# std      30.166206
# min       1.000000
# 25%      26.750000
# 50%      52.500000
# 75%      78.250000
# max     104.000000
#
#                                                                                                        job_title  \
# count                                                                                                        104
# unique                                                                                                        52
# top     2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# freq                                                                                                           7
# mean                                                                                                         NaN
# std                                                                                                          NaN
# min                                                                                                          NaN
# 25%                                                                                                          NaN
# 50%                                                                                                          NaN
# 75%                                                                                                          NaN
# max                                                                                                          NaN
#
#        location  connection
# count       104  104.000000
# unique       41         NaN
# top      Kanada         NaN
# freq         12         NaN
# mean        NaN  262.663462
# std         NaN  222.602812
# min         NaN    1.000000
# 25%         NaN   47.000000
# 50%         NaN  193.000000
# 75%         NaN  500.000000
# max         NaN  500.000000

# %%
# value counts of job_title column
df['job_title'].value_counts()
# Out:
# 2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional                 7
# Aspiring Human Resources Professional                                                                                    7
# Student at Humber College and Aspiring Human Resources Generalist                                                        7
# People Development Coordinator at Ryan                                                                                   6
# Native English Teacher at EPIK (English Program in Korea)                                                                5
# Aspiring Human Resources Specialist                                                                                      5
# HR Senior Specialist                                                                                                     5
# Student at Chapman University                                                                                            4
# SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR              4
# Human Resources Coordinator at InterContinental Buckhead Atlanta                                                         4
# Seeking Human Resources HRIS and Generalist Positions                                                                    4
# Advisory Board Member at Celal Bayar University                                                                          4
# Aspiring Human Resources Management student seeking an internship                                                        2
# Seeking Human Resources Opportunities                                                                                    2
# Seeking Human  Resources Opportunities. Open to travel and relocation.                                                   1
# Bachelor of Science in Biology from Victoria University of Wellington                                                    1
# Human Resources Management Major                                                                                         1
# Director Human Resources  at EY                                                                                          1
# Undergraduate Research Assistant at Styczynski Lab                                                                       1
# Lead Official at Western Illinois University                                                                             1
# Seeking employment opportunities within Customer Service or Patient Care                                                 1
# Admissions Representative at Community medical center long beach                                                         1
# Human Resources Generalist at Loparex                                                                                    1
# Student at Westfield State University                                                                                    1
# Student at Indiana University Kokomo - Business Management - \nRetail Manager at Delphi Hardware and Paint               1
# Student                                                                                                                  1
# Seeking Human Resources Position                                                                                         1
# Aspiring Human Resources Manager | Graduating May 2020 | Seeking an Entry-Level Human Resources Position in St. Louis    1
# RRP Brand Portfolio Executive at JTI (Japan Tobacco International)                                                       1
# Business Intelligence and Analytics at Travelers                                                                         1
# Always set them up for Success                                                                                           1
# Information Systems Specialist and Programmer with a love for data and organization.                                     1
# Human Resources Generalist at Schwan's                                                                                   1
# Human Resources professional for the world leader in GIS software                                                        1
# Aspiring Human Resources Manager, seeking internship in Human Resources.                                                 1
# Experienced Retail Manager and aspiring Human Resources Professional                                                     1
# Human Resources, Staffing and Recruiting Professional                                                                    1
# Human Resources Specialist at Luxottica                                                                                  1
# Director of Human Resources North America, Groupe Beneteau                                                               1
# Retired Army National Guard Recruiter, office manager,  seeking a position in Human Resources.                           1
# Human Resources Generalist at ScottMadden, Inc.                                                                          1
# Business Management Major and Aspiring Human Resources Manager                                                           1
# Human Resources Professional                                                                                             1
# HR Manager at Endemol Shine North America                                                                                1
# Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621                     1
# Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment    1
# Human Resources|\nConflict Management|\nPolicies & Procedures|Talent Management|Benefits & Compensation                  1
# Liberal Arts Major. Aspiring Human Resources Analyst.                                                                    1
# Junior MES Engineer| Information Systems                                                                                 1
# Senior Human Resources Business Partner at Heil Environmental                                                            1
# Aspiring Human Resources Professional | An energetic and Team-Focused Leader                                             1
# Director Of Administration at Excellence Logging                                                                         1
# Name: job_title, dtype: int64

# %%
# create cleaned job_title column for cleaned job
df['job_cleaned'] = df['job_title'].str.replace('Human Resources', 'HR')
df.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                   job_title  \
# 0  2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 1                                                 Native English Teacher at EPIK (English Program in Korea)
# 2                                                                     Aspiring Human Resources Professional
# 3                                                                    People Development Coordinator at Ryan
# 4                                                           Advisory Board Member at Celal Bayar University
#
#                               location  connection  \
# 0                       Houston, Texas          85
# 1                               Kanada         500
# 2  Raleigh-Durham, North Carolina Area          44
# 3                        Denton, Texas         500
# 4                       İzmir, Türkiye         500
#
#                                                                                    job_cleaned
# 0  2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring HR professional
# 1                                    Native English Teacher at EPIK (English Program in Korea)
# 2                                                                     Aspiring HR Professional
# 3                                                       People Development Coordinator at Ryan
# 4                                              Advisory Board Member at Celal Bayar University

# %%
# removal of punctuations in job_title_cleaned
df['job_cleaned'] = df['job_cleaned'].str.replace("[^a-zA-Z\s]",'', regex=True)
df['job_cleaned'] = df['job_cleaned'].str.lower()
df.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                   job_title  \
# 0  2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 1                                                 Native English Teacher at EPIK (English Program in Korea)
# 2                                                                     Aspiring Human Resources Professional
# 3                                                                    People Development Coordinator at Ryan
# 4                                                           Advisory Board Member at Celal Bayar University
#
#                               location  connection  \
# 0                       Houston, Texas          85
# 1                               Kanada         500
# 2  Raleigh-Durham, North Carolina Area          44
# 3                        Denton, Texas         500
# 4                       İzmir, Türkiye         500
#
#                                                                            job_cleaned
# 0   ct bauer college of business graduate magna cum laude and aspiring hr professional
# 1                              native english teacher at epik english program in korea
# 2                                                             aspiring hr professional
# 3                                               people development coordinator at ryan
# 4                                      advisory board member at celal bayar university

# %% [markdown]
# # Tokenize ----> Stopwords ----> Lemmetize ---> job_cleaned

# %%
# importing stopwords from nltk, wordnet lemmatizer, word tokenizer, TreebankWordTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, TreebankWordDetokenizer

# instance of lemmatizer
lemmatizer = WordNetLemmatizer()

# loop to remove stopwords and lemmatize

for i in range(len(df)):
    tokenized_words = word_tokenize(df['job_cleaned'][i])
    removed_stopwords = [word for word in tokenized_words if word not in set(stopwords.words('english'))]
    lemmatized_sentence = []
    for word in removed_stopwords:
        lemmatized_sentence.append(lemmatizer.lemmatize(word))
    df['job_cleaned'][i] = TreebankWordDetokenizer().detokenize(lemmatized_sentence)
# Out:
# /var/folders/97/2sz1zkqj3pl2ynflgjwjg_nh0000gn/T/ipykernel_50975/3744863170.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job_cleaned'][i] = TreebankWordDetokenizer().detokenize(lemmatized_sentence)

# %%
df.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                   job_title  \
# 0  2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 1                                                 Native English Teacher at EPIK (English Program in Korea)
# 2                                                                     Aspiring Human Resources Professional
# 3                                                                    People Development Coordinator at Ryan
# 4                                                           Advisory Board Member at Celal Bayar University
#
#                               location  connection  \
# 0                       Houston, Texas          85
# 1                               Kanada         500
# 2  Raleigh-Durham, North Carolina Area          44
# 3                        Denton, Texas         500
# 4                       İzmir, Türkiye         500
#
#                                                                    job_cleaned
# 0  ct bauer college business graduate magna cum laude aspiring hr professional
# 1                            native english teacher epik english program korea
# 2                                                     aspiring hr professional
# 3                                          people development coordinator ryan
# 4                                 advisory board member celal bayar university

# %%
# importing tf-idf
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()

# %%
jobs_list = list(df["job_cleaned"])
# transform into a vector 
jobs_list_tfidf = tfidf.fit_transform(jobs_list)

# needs to be an array to be passed into the cosign similarity 
jobs_list_tfidf.dtype
# Out:
# dtype('float64')

# %%
tfid_vector_jobs_list = jobs_list_tfidf.toarray()

# %%
# finding the cosine similarity between the phrases 
# vectorized difference 
sentence1 = "Aspiring human resources"
sentence2 = "seeking human resources"

# %%
# lemmetize the phrase 
lemmatized_sentence = []
word_tokenized = word_tokenize(sentence1.lower())
for word in word_tokenized:
    lemmatized_sentence.append(lemmatizer.lemmatize(word))
lemmatized_sentence = TreebankWordDetokenizer().detokenize(lemmatized_sentence)




# convert sentence phrase into a vector
X1 = tfidf.transform([lemmatized_sentence])
X1_vector = X1.toarray()
print('Shape of Sentence: ',X1_vector.shape)
# Out:
# Shape of Sentence:  (1, 176)

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import cosine

# %%
# consine similarity calculation for phrase1
# grab the similarity scores usinging cosign similarity 


similarity_score = []

for i in range(len(df)):
    similarity_score.append(cosine(X1_vector, tfid_vector_jobs_list[i]))
df['similarity_score_phrase1'] = similarity_score

df['similarity_score_phrase1'] = df['similarity_score_phrase1'].apply(lambda x: 1 - x)

sorted_df = df.sort_values(by='similarity_score_phrase1', ascending=False)
sorted_df.head()
# Out:
#     id  \
# 93  94
# 32  33
# 57  58
# 20  21
# 45  46
#
#                                                                  job_title  \
# 93  Seeking Human  Resources Opportunities. Open to travel and relocation.
# 32                                   Aspiring Human Resources Professional
# 57                                   Aspiring Human Resources Professional
# 20                                   Aspiring Human Resources Professional
# 45                                   Aspiring Human Resources Professional
#
#                                location  connection  \
# 93          Amerika Birleşik Devletleri         415
# 32  Raleigh-Durham, North Carolina Area          44
# 57  Raleigh-Durham, North Carolina Area          44
# 20  Raleigh-Durham, North Carolina Area          44
# 45  Raleigh-Durham, North Carolina Area          44
#
#                                                   job_cleaned  \
# 93  seeking human resource opportunity open travel relocation
# 32                                   aspiring hr professional
# 57                                   aspiring hr professional
# 20                                   aspiring hr professional
# 45                                   aspiring hr professional
#
#     similarity_score_phrase1
# 93                  0.553645
# 32                  0.162815
# 57                  0.162815
# 20                  0.162815
# 45                  0.162815

# %%
from gensim.test.utils import get_tmpfile
from gensim.models import Word2Vec, KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

# create temp file and save converted embedding
glove_file = get_tmpfile('word2vec.6B.50d.txt')

glove2word2vec('glove.6B.50d.txt', glove_file)

# load converted embedding into memory reference model 
glove_model = KeyedVectors.load_word2vec_format(glove_file)

# saving glove model
glove_model.save_word2vec_format('word2vec.6B.50d.bin.gz', binary=True)
# Out:
# /var/folders/97/2sz1zkqj3pl2ynflgjwjg_nh0000gn/T/ipykernel_50975/2657294514.py:8: DeprecationWarning: Call to deprecated `glove2word2vec` (KeyedVectors.load_word2vec_format(.., binary=False, no_header=True) loads GLoVE text vectors.).
#   glove2word2vec('glove.6B.50d.txt', glove_file)

# %%
def doc_token(sentence, model, sentence_vector_list, vector_dimensions):
    word_tokens = word_tokenize(sentence)
    words_being_filtered = [word for word in word_tokens if word in model.key_to_index.keys()]
    
    for i in range(len(word_tokens)):
        if word_tokens[i] in words_being_filtered:
            token_vector = model[word_tokens[i]]
        else:
            token_vector = np.zeros(vector_dimensions)
        sentence_vector_list.append(token_vector)
    
    return sentence_vector_list

# %%
# vectorize job title using glove model
glove_vectors = []
for i in range(len(df)):
    glove_sentence = []
    doc_token(sentence1, glove_model, glove_sentence , 50  )
    glove_vectors.append(glove_sentence)

# %%
# vectorize keyword phrase using glove model
glove_search_phrase = []
doc_token(lemmatized_sentence, glove_model, glove_search_phrase, 50)
# Out:
# [array([-4.3762e-01,  8.3236e-01,  2.9638e-01, -7.8180e-01,  2.4432e-01,
#          3.2892e-01, -8.2750e-01,  1.2692e-01, -3.9246e-01,  8.6643e-01,
#          2.4300e-01, -6.6664e-04,  5.2488e-01,  1.5963e+00,  3.8362e-01,
#         -3.2021e-01,  1.0324e+00,  7.0235e-01,  4.1679e-01, -2.0262e-01,
#          2.8378e-01,  9.4354e-01, -3.4941e-01,  1.4981e+00,  3.2488e-01,
#         -6.6963e-01, -4.2229e-01, -1.3033e+00, -5.9413e-01, -7.0466e-02,
#          7.0193e-01,  3.0914e-01, -4.0663e-01, -6.4972e-01,  7.7279e-01,
#          3.3412e-01, -8.0891e-01,  2.4861e-02, -5.1049e-01, -8.1757e-01,
#         -1.0251e-01,  5.6904e-01,  6.7411e-01, -1.9030e-01,  4.0583e-01,
#         -6.1531e-01,  2.2660e-01, -1.1493e-03, -6.5260e-01,  1.8631e-01],
#        dtype=float32),
#  array([ 0.61854 ,  0.11915 , -0.46786 ,  0.31368 ,  1.0334  ,  0.95964 ,
#          0.87803 , -1.0346  ,  1.6322  ,  0.29347 ,  0.80844 , -0.058903,
#          0.021251,  0.40986 ,  0.54443 , -0.33311 ,  0.53712 , -0.35823 ,
#          0.29374 ,  0.090151, -0.92049 ,  0.69386 ,  0.39098 , -0.64392 ,
#          0.77831 , -1.7215  , -0.48393 , -0.50327 , -0.22508 ,  0.099192,
#          3.2095  , -0.31554 , -0.71754 , -1.6752  , -1.3537  ,  0.15195 ,
#          0.054557, -0.1633  , -0.027993,  0.3917  , -0.55007 , -0.079205,
#          0.63389 ,  0.51446 ,  0.70124 ,  0.27638 , -0.53445 ,  0.064808,
#         -0.21974 , -0.52048 ], dtype=float32),
#  array([-3.1750e-01,  1.0283e-01,  2.2892e-01,  8.3472e-01,  6.9525e-01,
#         -5.3593e-01, -3.5810e-01, -6.5214e-01,  1.7119e+00,  2.1146e-01,
#          4.5018e-01,  6.1370e-01,  1.0889e+00, -3.2750e-01, -6.0655e-01,
#          1.1269e-01,  1.0554e+00,  3.9864e-01,  7.4542e-01, -1.2705e-01,
#          4.2323e-01, -1.3154e-01, -5.3286e-01, -2.6126e-01,  2.9638e-01,
#         -1.2541e-01, -1.2088e-01, -8.7959e-01,  3.9938e-01,  8.8202e-01,
#          2.8924e+00, -5.2737e-01,  2.4832e-01, -1.0702e+00,  1.8764e-03,
#          9.4444e-01, -9.4512e-01, -2.1192e-01,  8.3862e-01, -5.9163e-02,
#         -1.4186e-02, -4.2126e-01, -3.3418e-02,  7.3328e-01, -4.2880e-01,
#          1.3330e-01, -3.8570e-02,  1.0716e+00,  5.5300e-01,  2.3830e-01],
#        dtype=float32)]

# %%
vector_similarity_glove = []
for i in range(len(df)):
    similarity = cosine(np.mean(glove_vectors[i], axis=0), np.mean(glove_search_phrase, axis=0))
    vector_similarity_glove.append(similarity)

# %%
glove_similarity = []
for i in range(len(df)):
    similarity = cosine(np.mean(glove_vectors[i], axis=0), np.mean(glove_search_phrase, axis=0))
    glove_similarity.append(similarity)

    
df["glove_similarity_sentence1"] = glove_similarity

df["glove_similarity_sentence1"] = df["glove_similarity_sentence1"].apply(lambda x: 1 - x)

sorted_df = df.sort_values(by = "glove_similarity_sentence1", ascending= False)

sorted_df
# Out:
#       id  \
# 0      1
# 1      2
# 76    77
# 75    76
# 74    75
# ..   ...
# 31    32
# 30    31
# 29    30
# 28    29
# 103  104
#
#                                                                                                                  job_title  \
# 0                 2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 1                                                                Native English Teacher at EPIK (English Program in Korea)
# 76                 Human Resources|\nConflict Management|\nPolicies & Procedures|Talent Management|Benefits & Compensation
# 75   Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment
# 74                    Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621
# ..                                                                                                                     ...
# 31                                                               Native English Teacher at EPIK (English Program in Korea)
# 30                2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 29                                                                                   Seeking Human Resources Opportunities
# 28                                                       Aspiring Human Resources Management student seeking an internship
# 103                                                                       Director Of Administration at Excellence Logging
#
#                    location  connection  \
# 0            Houston, Texas          85
# 1                    Kanada         500
# 76   Dallas/Fort Worth Area         409
# 75       New York, New York         212
# 74     San Jose, California         500
# ..                      ...         ...
# 31                   Kanada         500
# 30           Houston, Texas          85
# 29        Chicago, Illinois         390
# 28      Houston, Texas Area         500
# 103             Katy, Texas         500
#
#                                                                                 job_cleaned  \
# 0               ct bauer college business graduate magna cum laude aspiring hr professional
# 1                                         native english teacher epik english program korea
# 76           hr conflict management policy procedurestalent managementbenefits compensation
# 75   aspiring hr professional passionate helping create inclusive engaging work environment
# 74                           nortia staffing seeking hr payroll administrative professional
# ..                                                                                      ...
# 31                                        native english teacher epik english program korea
# 30              ct bauer college business graduate magna cum laude aspiring hr professional
# 29                                                                   seeking hr opportunity
# 28                                        aspiring hr management student seeking internship
# 103                                              director administration excellence logging
#
#      similarity_score_phrase1  glove_similarity_sentence1  bert_scores  \
# 0                    0.056303                    0.875265     0.434025
# 1                    0.000000                    0.875265     0.141922
# 76                   0.000000                    0.875265     0.342546
# 75                   0.043060                    0.875265     0.544917
# 74                   0.000000                    0.875265     0.411955
# ..                        ...                         ...          ...
# 31                   0.000000                    0.875265     0.141922
# 30                   0.056303                    0.875265     0.434025
# 29                   0.000000                    0.875265     0.699841
# 28                   0.079304                    0.875265     0.601866
# 103                  0.000000                    0.875265     0.279863
#
#      mean_scores
# 0       0.455198
# 1       0.339062
# 76      0.405937
# 75      0.487747
# 74      0.429073
# ..           ...
# 31      0.339062
# 30      0.455198
# 29      0.525035
# 28      0.518811
# 103     0.385043
#
# [104 rows x 9 columns]

# %%
from sentence_transformers import SentenceTransformer

# %%
# shape being passed through NN = 384 
bert_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
bert_model_encoded_job = bert_model.encode(list(df["job_cleaned"]))
bert_model_encoded_job.shape
# Out:
# (104, 384)

# %%
bert_model_encoding_sentence1 = bert_model.encode(sentence1)
bert_model_encoding_sentence1.shape
# Out:
# (384,)

# %%
bert_score = []
for i in range(len(df)):
    similarity = cosine(bert_model_encoded_job[i], bert_model_encoding_sentence1)
    bert_score.append(1 - similarity)
    

df['bert_scores'] = bert_score

# viewing dataset by highest glove similarity scores
df_sorted5 = df.sort_values(by='bert_scores', ascending=False)
df_sorted5.head()
# Out:
#     id                              job_title  \
# 20  21  Aspiring Human Resources Professional
# 2    3  Aspiring Human Resources Professional
# 45  46  Aspiring Human Resources Professional
# 16  17  Aspiring Human Resources Professional
# 32  33  Aspiring Human Resources Professional
#
#                                location  connection               job_cleaned  \
# 20  Raleigh-Durham, North Carolina Area          44  aspiring hr professional
# 2   Raleigh-Durham, North Carolina Area          44  aspiring hr professional
# 45  Raleigh-Durham, North Carolina Area          44  aspiring hr professional
# 16  Raleigh-Durham, North Carolina Area          44  aspiring hr professional
# 32  Raleigh-Durham, North Carolina Area          44  aspiring hr professional
#
#     similarity_score_phrase1  glove_similarity_sentence1  bert_scores
# 20                  0.162815                    0.875265     0.803918
# 2                   0.162815                    0.875265     0.803918
# 45                  0.162815                    0.875265     0.803918
# 16                  0.162815                    0.875265     0.803918
# 32                  0.162815                    0.875265     0.803918

# %%
mean_scores = np.mean(df.iloc[:, -3:], axis = 1)
df["mean_scores"] = mean_scores

sorted_df = df.sort_values(ascending= False, by= "mean_scores")
sorted_df[sorted_df["id"] == 97]
# Out:
#     id                              job_title              location  \
# 96  97  Aspiring Human Resources Professional  Kokomo, Indiana Area
#
#     connection               job_cleaned  similarity_score_phrase1  \
# 96          71  aspiring hr professional                  0.162815
#
#     glove_similarity_sentence1  bert_scores  mean_scores
# 96                    0.875265     0.803918     0.613999

# %%
df2 = df.copy()

# %%
# getting the candidates who needs to be starred or not... takes the input and chjanges the score sequencially  
star_candidate_input = input("Candidates Starred: Enter y  or n ")
star_candidate_input.lower()

starred_candidates = []
if star_candidate_input == 'y':
    starred = [int(num) for num in input("Get the candidate id that needs to be starred").split()]
# Out:
# Candidates Starred: Enter y  or n y
# Get the candidate id that needs to be starred7 8 7

# %%
starred
# Out:
# [7, 8, 7]

# %%
df2["starred"] = df["mean_scores"]

for star in starred:
    df2.loc[df2['id'] == star, 'starred'] = 1

# viewing first 5 observations of df_rank
df2.head()
# Out:
#    id  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                   job_title  \
# 0  2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional
# 1                                                 Native English Teacher at EPIK (English Program in Korea)
# 2                                                                     Aspiring Human Resources Professional
# 3                                                                    People Development Coordinator at Ryan
# 4                                                           Advisory Board Member at Celal Bayar University
#
#                               location  connection  \
# 0                       Houston, Texas          85
# 1                               Kanada         500
# 2  Raleigh-Durham, North Carolina Area          44
# 3                        Denton, Texas         500
# 4                       İzmir, Türkiye         500
#
#                                                                    job_cleaned  \
# 0  ct bauer college business graduate magna cum laude aspiring hr professional
# 1                            native english teacher epik english program korea
# 2                                                     aspiring hr professional
# 3                                          people development coordinator ryan
# 4                                 advisory board member celal bayar university
#
#    similarity_score_phrase1  glove_similarity_sentence1  bert_scores  \
# 0                  0.056303                    0.875265     0.434025
# 1                  0.000000                    0.875265     0.141922
# 2                  0.162815                    0.875265     0.803918
# 3                  0.000000                    0.875265     0.378423
# 4                  0.000000                    0.875265     0.201885
#
#    mean_scores   starred
# 0     0.455198  0.455198
# 1     0.339062  0.339062
# 2     0.613999  0.613999
# 3     0.417896  0.417896
# 4     0.359050  0.359050

# %% [markdown]
# # Make the Neural Network

# %%
# make the model 
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class Net(nn.Module):
    def __init__(self, n_features):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(n_features, 256), 
            nn.Dropout(0.5),
            nn.ReLU(inplace= True),
            nn.Linear(256, 128),
            nn.Dropout(0.5), 
            nn.ReLU(inplace = True), 
            nn.Linear(128, 64), 
            nn.ReLU(inplace = True), 
            nn.Linear(64, 1), 
            nn.Sigmoid(),
        )
        self.output_sigmoid = nn.Sigmoid()
        
    def forward(self, x, y):
        
        system1 = self.net(x)
        system2 = self.net(y)
        output = self.output_sigmoid(system1-system2)
        return output
    
    
    def predict(self, inputs):
        
        s = self.net(inputs)
        return s

# %%
row_1 = df2.sample( n=2000, replace= True)
row_2 = df2.sample( n=2000, replace= True)
job_list1 = list(row_1["job_cleaned"])
job_list2 = list(row_2["job_cleaned"])
job_list_1_encoded = bert_model.encode(job_list1)
job_list_2_encoded = bert_model.encode(job_list2)
type(job_list_1_encoded)
# Out:
# numpy.ndarray

# %%
import torch.optim as optim

# %%
# changing the numpy into Tensor to pass into the model 
sentence_1 = torch.from_numpy(job_list_1_encoded).float()
sentence_2 = torch.from_numpy(job_list_2_encoded).float()


print(type(sentence_1))
print(type(sentence_2))
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %%
# Make the True Values for the models 
y1 = list(row_1['starred'])
y2 = list(row_2['starred'])
y = torch.Tensor([1 if y1_i > y2_i else 0.5 if y1_i == y2_i else 0 for y1_i, y2_i in zip(y1, y2)]).float()
y = y.unsqueeze(-1)

# %%
model = Net(n_features= 384)

# %%
# define model, define the optomizer , define the  loss function

optimizer = optim.Adam(model.parameters(), lr = .0001)

loss_func = nn.BCELoss()


# defining the Epochs 
epochs = 1000
losses = []


# training the system
for i in range(epochs):
    model.zero_grad()
    # model.zero_grad() ---> predict ---> loss ---> optimization ---> backward() ---> step()
    y_pred = model(sentence_1, sentence_2)
    # predict ---> loss ---> backward ---> optimizer
    loss = loss_func(y_pred, y)
    loss.backward()
    optimizer.step()
    losses.append(loss.item())
    if i % 100 == 1:
        print(f"Epoch {i} Loss {loss.item()}")
# Out:
# Epoch 1 Loss 0.6929510235786438
# Epoch 101 Loss 0.6280466914176941
# Epoch 201 Loss 0.5096757411956787
# Epoch 301 Loss 0.5012503862380981
# Epoch 401 Loss 0.5003368854522705
# Epoch 501 Loss 0.5000662803649902
# Epoch 601 Loss 0.49996417760849
# Epoch 701 Loss 0.49987098574638367
# Epoch 801 Loss 0.49885860085487366
# Epoch 901 Loss 0.4993155896663666

# %%
predictions = []

for i in range(len(df2)):
    job_sentence_embedded = bert_model.encode(df2["job_cleaned"][i])
    job_sentences_to_tensor = torch.from_numpy(job_sentence_embedded).float()
    pred = round(model.predict(job_sentences_to_tensor).detach().numpy().sum(), 2)
    predictions.append(pred)

df2["Ranked_preds"] = predictions


sorted_ranked = df2.sort_values(ascending= False, by = "Ranked_preds")
    
    
sorted_ranked
# Out:
#       id  \
# 26    27
# 23    24
# 25    26
# 27    28
# 28    29
# ..   ...
# 33    34
# 31    32
# 22    23
# 54    55
# 103  104
#
#                                                                                                        job_title  \
# 26                                             Aspiring Human Resources Management student seeking an internship
# 23                                                                           Aspiring Human Resources Specialist
# 25                                                                                          HR Senior Specialist
# 27                                                                         Seeking Human Resources Opportunities
# 28                                             Aspiring Human Resources Management student seeking an internship
# ..                                                                                                           ...
# 33                                                                        People Development Coordinator at Ryan
# 31                                                     Native English Teacher at EPIK (English Program in Korea)
# 22                                                               Advisory Board Member at Celal Bayar University
# 54   SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR
# 103                                                             Director Of Administration at Excellence Logging
#
#                        location  connection  \
# 26          Houston, Texas Area         500
# 23   Greater New York City Area           1
# 25       San Francisco Bay Area         500
# 27            Chicago, Illinois         390
# 28          Houston, Texas Area         500
# ..                          ...         ...
# 33                Denton, Texas         500
# 31                       Kanada         500
# 22               İzmir, Türkiye         500
# 54          Houston, Texas Area         500
# 103                 Katy, Texas         500
#
#                                                                               job_cleaned  \
# 26                                      aspiring hr management student seeking internship
# 23                                                                 aspiring hr specialist
# 25                                                                   hr senior specialist
# 27                                                                 seeking hr opportunity
# 28                                      aspiring hr management student seeking internship
# ..                                                                                    ...
# 33                                                    people development coordinator ryan
# 31                                      native english teacher epik english program korea
# 22                                           advisory board member celal bayar university
# 54   svp chro marketing communication csr officer engie houston woodland energy gphr sphr
# 103                                            director administration excellence logging
#
#      similarity_score_phrase1  glove_similarity_sentence1  bert_scores  \
# 26                   0.079304                    0.875265     0.601866
# 23                   0.146835                    0.875265     0.719585
# 25                   0.000000                    0.875265     0.503457
# 27                   0.000000                    0.875265     0.699841
# 28                   0.079304                    0.875265     0.601866
# ..                        ...                         ...          ...
# 33                   0.000000                    0.875265     0.378423
# 31                   0.000000                    0.875265     0.141922
# 22                   0.000000                    0.875265     0.201885
# 54                   0.000000                    0.875265     0.248271
# 103                  0.000000                    0.875265     0.279863
#
#      mean_scores   starred  Ranked_preds
# 26      0.518811  0.518811           1.0
# 23      0.580561  0.580561           1.0
# 25      0.459574  0.459574           1.0
# 27      0.525035  0.525035           1.0
# 28      0.518811  0.518811           1.0
# ..           ...       ...           ...
# 33      0.417896  0.417896           0.0
# 31      0.339062  0.339062           0.0
# 22      0.359050  0.359050           0.0
# 54      0.374512  0.374512           0.0
# 103     0.385043  0.385043           0.0
#
# [104 rows x 11 columns]
